# %% [markdown]
# <a href="https://colab.research.google.com/github/Darshijain14/oibsip_taskno5/blob/main/Sales_prediction_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###  **Project Title** - Sales prediction using python
#
# **Name** - Darshi Jain
# **Project Type** - Regression
# **Industry** - Oasis Infobyte
# **Task** - 5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Darshijain14/oibsip_taskno5/refs/heads/main/Advertising.csv")
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# ### **Exploring data**

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
data = data.drop(columns=["Unnamed: 0"])

# %% [markdown]
# ### **Data Cleaning**

# %%
data.isnull()
# Out:
#         TV  Radio  Newspaper  Sales
# 0    False  False      False  False
# 1    False  False      False  False
# 2    False  False      False  False
# 3    False  False      False  False
# 4    False  False      False  False
# ..     ...    ...        ...    ...
# 195  False  False      False  False
# 196  False  False      False  False
# 197  False  False      False  False
# 198  False  False      False  False
# 199  False  False      False  False
#
# [200 rows x 4 columns]

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# ### **Running various operations**

# %%
data = data.astype("int")
data.head()
# Out:
#     TV  Radio  Newspaper  Sales
# 0  230     37         69     22
# 1   44     39         45     10
# 2   17     45         69      9
# 3  151     41         58     18
# 4  180     10         58     12

# %%
data["Sales"].mean()
# Out:
# np.float64(13.54)

# %%
data["Sales"].std()
# Out:
# 5.253225857465844

# %%
 # New column added named Qty
data["Qty"] = "5"
data.head()
# Out:
#     TV  Radio  Newspaper  Sales Qty
# 0  230     37         69     22   5
# 1   44     39         45     10   5
# 2   17     45         69      9   5
# 3  151     41         58     18   5
# 4  180     10         58     12   5

# %%
data.duplicated(subset = ["TV","Newspaper","Radio"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
data["TV"] + 10
# Out:
# 0      240
# 1       54
# 2       27
# 3      161
# 4      190
#       ...
# 195     48
# 196    104
# 197    187
# 198    293
# 199    242
# Name: TV, Length: 200, dtype: int64

# %%
data["Radio"] / 2
# Out:
# 0      18.5
# 1      19.5
# 2      22.5
# 3      20.5
# 4       5.0
#        ...
# 195     1.5
# 196     2.0
# 197     4.5
# 198    21.0
# 199     4.0
# Name: Radio, Length: 200, dtype: float64

# %%
data.iloc[range(0, 100, 10)]
# Out:
#      TV  Radio  Newspaper  Sales Qty
# 0   230     37         69     22   5
# 10   66      5         24      8   5
# 20  218     27         53     18   5
# 30  292     28         43     21   5
# 40  202     22         31     16   5
# 50  199      3         34     11   5
# 60   53      2         21      8   5
# 70  199     30         38     18   5
# 80   76     26         22     11   5
# 90  134      4          9     11   5

# %%
data.sample(n=5)
# Out:
#       TV  Radio  Newspaper  Sales Qty
# 13    97      7          7      9   5
# 86    76     27         16     12   5
# 153  171     39         37     19   5
# 120  141     26         46     15   5
# 138   43     25         20      9   5

# %% [markdown]
# ### **Data Visualization**

# %%
sns.pairplot(data, plot_kws={"color": "skyblue"})

# %%
sns.pairplot(data,x_vars=["Newspaper","TV","Radio"],y_vars="Sales",kind="scatter",)
plt.show()

# %%
sns.histplot(data["Sales"], color="lightseagreen")
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.jointplot(x="Newspaper", y="Sales", data=data, color="teal", kind="scatter")

# %%
del data["Qty"]

# %%
correlation=data.corr()

# %%
sns.heatmap(correlation, annot=True, cmap="YlGnBu", linewidths=0.5, linecolor='gray')
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# It can be concluded that TV has the strongest correlation with Sales.

# %%
# dividing the dataset into training and testing sets
from sklearn.model_selection import train_test_split
X = data[["TV","Radio","Newspaper"]]
y = data[["Sales"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print(X_train)
# Out:
#       TV  Radio  Newspaper
# 169  284     10          6
# 97   184     21         22
# 31   112     17         38
# 12    23     35         65
# 35   290      4          8
# ..   ...    ...        ...
# 106   25     11         29
# 14   204     32         46
# 92   217     33         59
# 179  165     10         17
# 102  280     10         21
#
# [140 rows x 3 columns]

# %%
print(y_train)
# Out:
#      Sales
# 169     15
# 97      15
# 31      11
# 12       9
# 35      12
# ..     ...
# 106      7
# 14      19
# 92      19
# 179     12
# 102     14
#
# [140 rows x 1 columns]

# %%
print(X_test)
# Out:
#       TV  Radio  Newspaper
# 95   163     31         52
# 15   195     47         52
# 30   292     28         43
# 158   11     36         45
# 128  220     49          3
# 115   75     35         52
# 69   216     43         27
# 170   50     11         18
# 174  222      3         13
# 45   175     22         31
# 66    31     24          2
# 182   56      5         29
# 165  234      3         84
# 78     5     29          9
# 186  139      2         26
# 177  170      7         35
# 56     7     28         41
# 152  197     23         14
# 82    75     20         32
# 68   237     27         11
# 124  229     32         74
# 16    67     36        114
# 148   38     40         11
# 93   250     36         72
# 65    69      9          0
# 60    53      2         21
# 84   213     43         33
# 67   139     14         10
# 125   87     11         25
# 132    8     27          2
# 9    199      2         21
# 18    69     20         18
# 55   198     49         60
# ...

# %%
print(y_test)
# Out:
#      Sales
# 95      16
# 15      22
# 30      21
# 158      7
# 128     24
# 115     12
# 69      22
# 170      8
# 174     11
# 45      14
# 66       9
# 182      8
# 165     11
# 78       5
# 186     10
# 177     11
# 56       5
# 152     16
# 82      11
# 68      18
# 124     19
# 16      12
# 148     10
# 93      22
# 65       9
# 60       8
# 84      21
# 67      13
# 125     10
# 132      5
# 9       10
# 18      11
# 55      23
# 75       8
# 150     16
# 104     20
# 135     11
# 137     20
# 164     11
# 76       6
# 79      11
# 197     12
# 38      10
# 24       9
# 122     11
# 195      7
# 29      10
# 19      14
# 143     10
# 86      12
# 114     14
# 173     11
# 5        7
# 126      6
# 117      9
# 73      11
# 140     10
# 98      25
# 172      7
# 96      11

# %% [markdown]
# ### **Model Training**

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# generating predictions using the test data
predictions = model.predict(X_test)
print(predictions)
# Out:
# [[16.12149679]
#  [20.79103718]
#  [21.14893373]
#  [10.37132374]
#  [21.95647179]
#  [13.04596673]
#  [20.72863357]
#  [ 6.81783175]
#  [12.75675726]
#  [14.67233604]
#  [ 8.50985806]
#  [ 5.94006298]
#  [13.78904186]
#  [ 8.42748133]
#  [ 8.9768522 ]
#  [11.42784495]
#  [ 8.53864074]
#  [15.7279449 ]
#  [ 9.85279763]
#  [18.28842715]
#  [19.39747775]
#  [13.33413919]
#  [12.13809631]
#  [21.12528567]
#  [ 7.12342359]
#  [ 5.14056087]
#  [20.63845827]
#  [11.30516992]
#  [ 8.50260706]
#  [ 8.10368292]
#  [11.59332768]
#  [ 9.48864525]
#  [21.38708708]
#  [12.3275235 ]
#  [17.52437042]
#  [19.71437385]
#  [13.9830242 ]
#  [20.42229888]
#  [10.2974887 ]
#  [ 3.78091651]
#  [ 8.95637359]
#  [11.93911894]
#  [ 9.68041372]
#  [ 7.55164836]
#  [12.65583771]
#  [ 4.6245032 ]
#  [ 8.87455802]
#  [13.55343975]
#  [ 8.09686706]
#  [11.20805134]
#  [15.28928474]
#  [11.17685701]
#  [12.8922381 ]
#  [10.63678651]
#  [ 5.70070312]
#  [ 9.18058499]
#  [ 9.01266097]
#  [23.92122794]
# ...

# %%
model.intercept_
# Out:
# array([2.24275844])

# %%
model.coef_
# Out:
# array([[0.04419703, 0.20345221, 0.0070693 ]])

# %%
# predicting sales for a TV budget of 90
tv_spend = 90
slope = 0.05473199
intercept = 7.14382225

predicted_sales = slope * tv_spend + intercept
print(predicted_sales)
# Out:
# 12.06970135

# %% [markdown]
# ### **Accuracy**

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, y_pred)
print("R² Score (Linear Regression):", r2 * 100)
# Out:
# R² Score (Linear Regression): 85.4709692294124
